# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1D Tensor

# %%
x = torch.FloatTensor(5)
x
# Out:
# -3.7641e-37
#  9.5560e+21
#  2.8494e-14
#  7.6546e-38
#  2.4442e+20
# [torch.FloatTensor of size 5]

# %% [markdown]
# ### 2D Tensor

# %%
from sklearn.datasets import load_iris

iris = load_iris()
iris.data.shape
# Out:
# (150, 4)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris_tensor = torch.from_numpy(iris.data)
iris_tensor.size()
# Out:
# torch.Size([150, 4])

# %%
from PIL import Image

panda = np.array(Image.open('data/panda.jpg'))
panda_tensor = torch.from_numpy(panda)
panda_tensor.size()
# Out:
# torch.Size([718, 960, 3])

# %%
plt.imshow(panda)

# %%
plt.imshow(panda_tensor[:,:,0].numpy());

# %%
plt.imshow(panda_tensor[200:500,100:500,:].numpy());

# %%
diagonal = torch.eye(3,3)
diagonal
# Out:
#  1  0  0
#  0  1  0
#  0  0  1
# [torch.FloatTensor of size 3x3]
